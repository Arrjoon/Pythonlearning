# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
xpoint = np.array([0,6])
ypoint = np.array([0,250])
plt.plot(xpoint,ypoint)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create an array of x-values from 0 to 2*pi (you can adjust the range as needed)
x = np.linspace(0, 2*np.pi, 1000)

# Calculate the corresponding y-values using the sine function
y = np.sin(x)

# Create the plot
plt.plot(x, y)

# Add labels and title
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.title('Sine Wave')
# Out:
# Text(0.5, 1.0, 'Sine Wave')

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate some random data (replace this with your dataset)
data = np.random.normal(loc=0, scale=1, size=1000)

# Create the histogram
plt.hist(data, bins=20, color='blue', alpha=0.7)  # You can adjust the number of bins and colors

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')

# Show the plot
plt.show()
